# %% [markdown]
# ##Integrantes:
# - Matheus de S. Santos Rm566901
# - Ricardo José Amorin Rm567312
# - Klaus Lohany Barbosa de Oliveira
# - Victor Oliveira Fedeli Tate Rm566823
# - Paulo Roberto Silva Amaral Ribeiro Junior Rm568413

# %% [markdown]
# ##FASE 6 - Colheita de Soluções Inteligentes - Transformando dados em ações

# %% [markdown]
# #CONECTANDO AO DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #COPIANDO REPOSITORIO DO GITHUB

# %%
! git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17898, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 17898 (delta 58), reused 22 (delta 22), pack-reused 17822 (from 2)
# Receiving objects: 100% (17898/17898), 17.02 MiB | 19.87 MiB/s, done.
# Resolving deltas: 100% (12191/12191), done.

# %%
#Instalando os requerimentos do yolov5
! pip install -r yolov5/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 17.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ...

# %%
# !cp /content/drive/MyDrive/farmtech/galinha.yaml yolov5/data/

# %% [markdown]
# #TREINAMENTO COM AS IMAGENS DO DRIVE

# %% [markdown]
# foi utilizado o arquivo "galinha.yaml"  contido no drive com parametros para a rotulagem das imagens (galinha ou raposa) , como paremetros de treinamento iniciamos com uma padronização do tamanho da imagem de 416x416 para manter uma boa qualidade na detecção e 30 epocas para avaliar o modelo

# %%
# !python yolov5/train.py --data galinha.yaml --weights yolov5s.pt --img 416 --epochs 30
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 3
# wandb: You chose "Don't visualize my results"
# wandb: Using W&B in offline mode.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# ...

# %% [markdown]
# conseguimos observar que com 30 epocas o modelo rapresentou uma precisão media de 0.75 e um recall de 0.75 já o mAP50 ficou em 0.83 , o mAP50 - 95 tambem ficou em niveis não satisfatorios

# %%
import os
import subprocess

def get_latest_train_run_folder():
    subfolders = [f.path for f in os.scandir('yolov5/runs/train') if f.is_dir()]
    latest_folder = max(subfolders, key=os.path.getctime, default=None)
    return latest_folder

latest_run = get_latest_train_run_folder()
result = subprocess.run(f'python yolov5/detect.py --weights {latest_run}/weights/best.pt --img 640 --source drive/MyDrive/farmtech/test/ --data yolov5/data/galinha.yaml', shell=True, capture_output=True, text=True)
if latest_run:
    # COMANDO
    result = subprocess.run(f'python yolov5/detect.py --weights {latest_run}/weights/best.pt --img 640 --source drive/MyDrive/farmtech/test/ --data yolov5/data/galinha.yaml', shell=True, capture_output=True, text=True)
    print(result.stdout)
    print(result.stderr)
else:
    print("Não foi possível encontrar a pasta de treinamento mais recente.")
# Out:
# detect: weights=['yolov5/runs/train/exp/weights/best.pt'], source=drive/MyDrive/farmtech/test/, data=yolov5/data/galinha.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-478-g6c66ecd5 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/8 /content/drive/MyDrive/farmtech/test/brett-jordan-tp9Y4_w9DIA-unsplash.jpg: 480x640 (no detections), 32.6ms
# image 2/8 /content/drive/MyDrive/farmtech/test/bri-tucker-BSvRfFDCO7U-unsplash.jpg: 448x640 1 galinha, 34.2ms
# ...

# %% [markdown]
# #60 EPOCAS

# %% [markdown]
# Agora utilizaremos os mesmos parametros de treinamento porem com 60 epocas

# %%
# !python yolov5/train.py --data galinha.yaml --weights yolov5s.pt --img 416 --epochs 60
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 3
# wandb: You chose "Don't visualize my results"
# wandb: Using W&B in offline mode.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# ...

# %% [markdown]
# O modelo obteve uma melhora significativa, a precisão geral ficou proximo a 91% enquanto o recall atingiu 100% , o mAP50 tambem performou muito bem , porem quando olhamos para o mAP50-95 identificamos que apesar da melhora ainda não é suficiente para um uso profissional , para obter uma melhora teria que treinar o modelo com mais imagens, ajustar o tamanho da imagem para um valor mais adequado (maior que 416x416) e treinar mais epocas.

# %%
import os
import subprocess

def get_latest_train_run_folder():
    subfolders = [f.path for f in os.scandir('yolov5/runs/train') if f.is_dir()]
    latest_folder = max(subfolders, key=os.path.getctime, default=None)
    return latest_folder

latest_run = get_latest_train_run_folder()
result = subprocess.run(f'python yolov5/detect.py --weights {latest_run}/weights/best.pt --img 640 --source drive/MyDrive/farmtech/test/ --data yolov5/data/galinha.yaml', shell=True, capture_output=True, text=True)
if latest_run:
    # COMANDO
    result = subprocess.run(f'python yolov5/detect.py --weights {latest_run}/weights/best.pt --img 640 --source drive/MyDrive/farmtech/test/ --data yolov5/data/galinha.yaml', shell=True, capture_output=True, text=True)
    print(result.stdout)
    print(result.stderr)
else:
    print("Não foi possível encontrar a pasta de treinamento mais recente.")
# Out:
# detect: weights=['yolov5/runs/train/exp/weights/best.pt'], source=drive/MyDrive/farmtech/test/, data=yolov5/data/galinha.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-478-g6c66ecd5 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/8 /content/drive/MyDrive/farmtech/test/brett-jordan-tp9Y4_w9DIA-unsplash.jpg: 480x640 (no detections), 49.6ms
# image 2/8 /content/drive/MyDrive/farmtech/test/bri-tucker-BSvRfFDCO7U-unsplash.jpg: 448x640 1 galinha, 34.4ms
# ...

# %% [markdown]
# ##CONSLUSÃO

# %% [markdown]
# A conslusão que chegamos é que esse modelo é adequado para uma apresentação a um cliente , pois demonstra bem a funcionalidade e tem uma precisão satisfatoria , para a produção teria que ser feitos ajustes e adicionar mais imagens ao dataframe para melhorar o desempemnho do modelo para um uso comercial.
